# %%
print('ayo ukur berat badan anda')
print('=========================')

massa_03=float(input("berapa massamu? "))
satuan_03=input("(K)g atau (G)ram? ")
if satuan_03.upper() == "K":
    converted_1_03 = massa_03*1000
    converted_2_03 = massa_03*9,8
    print("massa badanmu adalah: " + str(converted_1_03) + ' kg')
    print("berat badanmu adalah: " + str(converted_2_03) + ' N')
    if massa_03 >= 70:
        print('yahaha, berat banget') 
elif satuan_03.upper() == "G":
    converted_1_03 = massa_03/1000
    converted_2_03 = massa_03*9,8
    print("massa badanmu adalah: " + str(converted_1_03) + ' kg')
    print("berat badanmu adalah: " + str(converted_2_03) + ' N')
    if massa_03 >= 70:
        print('yahaha, berat banget')
    
else: 
    print ("silahkan pilih k atau g yaa")
    quit()
# Out:
# ayo ukur berat badan anda
# ...
# berapa massamu?  70
# (K)g atau (G)ram?  k
# massa badanmu adalah: 70000.0 kg
# berat badanmu adalah: (630.0, 8) N
# yahaha, berat banget

# %%
n_03=6
for i in range(n_03):
    for j in range (i):
        print (" ", end=' ')
    for j in range (i,n_03):
        print ('*', end=' ')
    for j in range (7-i):
        print('*', end=' ')
    print()
for i in range(n):
    for j in range (i,n_03):
        print (" ", end=' ')
    for j in range (i+1):
        print('*',end=' ')
    for j in range (i):
        print('*',end=' ')
    print()
# Out:
# * * * * * * * * * * * * *
#   * * * * * * * * * * *
#     * * * * * * * * *
#       * * * * * * *
#         * * * * *
#           * * *
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *

# %%
n_03=6
for i in range(n_03):
    for j in range (i,n_03):
        print (" ", end=' ')
    for j in range (i+1):
        print('*',end=' ')
    for j in range (i):
        print("*",end=' ')
    print()
for i in range(n_03):
    for j in range (i,n_03):
        print (" ", end=' ')
    for j in range (i+1):
        print('*',end=' ')
    for j in range (i):
        print('*',end=' ')
    print()
for i in range(n):
    for j in range(5):
        print(" ", end=' ')
    for j in range (n_03-3):
        print("*",end=" ")
    print()
# Out:
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *
#           * * *
#           * * *
#           * * *
#           * * *
#           * * *
#           * * *
