# %%
nama_03=input(f'siapa nama mu? ')
kegiatan_03=input(f"lagi apa sekarang, " + nama_03 + f'? ')
kalimat_03= f'Jangan lupa istirahat, setelah ' + kegiatan_03 + ' ya, ' + nama_03
print(kalimat_03)

# %%
kelas_03='Wirya ramah ganteng jelas keren'
print('Wirya '+ kelas_03[8:])
# Out:
# Wirya mah ganteng jelas keren

# %%
print('PROGRAM MENGHITUNG KELILING SEGITIGA')
print('====================================')

s1_03=float(input('masukkan sisi pertama: '))
s2_03=float(input('masukkan sisi kedua: '))
s3_03=float(input('masukkan sisi ketiga: '))

kell_03=s1+s2+s3

print('Keliling segitiga sebesar ', kell_03 , ' cm')

# %%
print ('Luas Permukaan Balok')
print ('====================')

p_03=float(input ('masukkan panjang: '))
l_03=float(input('masukkan lebar: '))
t_03=float(input('masukkan tinggi: '))

luas_03=((2*p_03*l_03)+(2*p_03*t_03)+(2*l_03*t_03))

print('Luas permukaan balok sebesar ', luas_03 , ' cm^2')
# Out:
# Luas Permukaan Balok
# ...
# masukkan panjang:  10
# masukkan lebar:  8
# masukkan tinggi:  12
# Luas permukaan balok sebesar  592.0  cm^2

# %%
print('PERMAINAN TEBAK ANGKA')
print('=====================')

x_03=float(input("masukkan angka: "))
x_03+=4
print(x_03 > 7 and x_03 < 31)
# Out:
# PERMAINAN TEBAK ANGKA
# ...
# masukkan angka:  24
# True

# %%
fakta_03='Wirya jelek banget'
fakta_03.replace('jelek','ganteng')
# Out:
# 'WIRYA JELEK BANGET'

# %%
fakta_03.upper()
# Out:
# 'WIRYA JELEK BANGET'

# %%
print('jelek' in fakta_03)
# Out:
# True
