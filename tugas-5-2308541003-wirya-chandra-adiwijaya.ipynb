# %%
def fibonacci_03(w_03):
    if w_03==0:
        return 0
    elif w_03==1:
        return 1
    else:
        return fibonacci_03(w_03-1) + fibonacci_03(w_03-2)

def jumlah_fibo_03(w_03):
    sum = 0
    for i_03 in range (w_03):
        sum += fibonacci_03(i_03)
    return sum

deret_03=True
while deret_03:
    print('Program Menghitung Jumlah Deret Bilangan Fibonacci')
    print('==================================================')
    n_03=int(input('Silahkan masukkan angka untuk baris bilangan Fibonacci (0 < bilangan fibonacci < 30): '))
    if 0<=n_03<=30: 
        print(f'Deret bilangan Fibonacci ke-{n_03}')
        for a_03 in range(n_03):
            print(fibonacci_03(a_03))
    else:
        if n_03<0:
            print(f'Angka {n_03} terlalu kecil untuk program ini')
        elif n_03>30:
            print(f'Angka {n_03} terlalu besar untuk program ini')
        else:
            print('Silahkan masukkan angka sesuai ketentuan')
    hasil=jumlah_fibo_03(n_03)
    print(f'Jumlah {n_03} deret bilangan fibonacci adalah {hasil}')
    print('')
    
    while True:
        ulang_03=input('Apakah anda ingin memulai ulang program (y / t): ')
        if ulang_03.casefold()=='y':
            baris_03=False
            break
        elif ulang_03.casefold()=='t':
            baris_03=True
            print('Terima kasih')
            break
        else:
            print('Silahkan masukkan jawaban yang benar')
            
    if baris_03:
        break
    print('')

# %%
print('PROGRAM TRANSPOSE MATRIKS')
print('=========================')

baris_03=int(input('Silahkan masukkan jumlah baris matriks: '))
kolom_03=int(input('Silahkan masukkan jumlah kolom matriks: '))

matrix_03=[]
print('Silahkan masukkan entri matriks: ')

for a_03 in range(baris_03):
    buat_baris_03=[]
    for r_03 in range(kolom_03):
        buat_baris_03.append(int(input()))
    matrix_03.append(buat_baris_03)

print('')
for a_03 in range(baris_03):
    for r_03 in range(kolom_03):
        print(matrix_03[a_03][r_03], end=' ')
    print()

hasil_03=matrix_03.append(buat_baris_03)

transposed_matrix_03 = []
for i in range(kolom_03):
    transposed_row = []
    for j in range(baris_03):
        transposed_row.append(matrix_03[j][i])
    transposed_matrix_03.append(transposed_row)

print('\nTranspos Matriks:')
for row in transposed_matrix_03:
    for element in row:
        print(element, end=' ')
    print()

# %%
def display(nama_03, absen_03):
    print("Nama: ", nama_03)
    print("Absen: ", absen_03)
    print("Nilai: ", nilai_03)
    print()

def search(absen_03, daftar_03):
    for siswa_03 in daftar_03:
        if siswa_03[1] == absen_03: 
            return siswa_03
    return None

def input_siswa_03():
    nama_03 = input("Masukkan nama siswa: ")
    absen_03 = input("Masukkan absen siswa: ")
    nilai_03 = input("Masukkan nilai siswa: ")
    return (nama_03, absen_03)

def checker_siswa_03(daftar_03, nama_03, absen_03):
    nama_siswa_sudah_ada_03 = absen_siswa_sudah_ada_03 = False
    for a_03,r_03 in daftar_03:
        if nama_03 == a_03:
            print(f"{nama_03} sudah ada di dalam data ini, silahkan masukkan nama lain")
            nama_siswa_sudah_ada_03 = True
        if absen_03 == r_03:
            print(f"{absen_03} sudah ada di dalam data ini, silahkan masukkan absen lain")
            absen_siswa_sudah_ada_03 = True
    return nama_siswa_sudah_ada_03, absen_siswa_sudah_ada_03

print('PROGRAM SEARCHING SISWA')
print('===========================')

daftar_03 = []

jumlah_03 = int(input('Masukkan jumlah siswa: '))

for a_03 in range(jumlah_03):
    siswa_03 = input_siswa_03()
    nama_siswa_sudah_ada_03, absen_siswa_sudah_ada_03 = checker_siswa_03(daftar_03, *siswa_03)
    if not (nama_siswa_sudah_ada_03 or absen_siswa_sudah_ada_03):
        daftar_03.append(siswa_03)
    print('')

absen_search_03 = input("Masukkan absen yang ingin dicari: ")
hasil_03 = search(absen_search_03, daftar_03)
if hasil_03:
    print("Siswa dengan absen", absen_search_03, "ketemu")
    display(*hasil_03)
else:
    print("Siswa dengan absen", absen_search_03, "gak ketemu")
# Out:
# PROGRAM SEARCHING SISWA
# ...
# Masukkan jumlah siswa:  2
# Masukkan nama siswa:  wirya
# Masukkan absen siswa:  2
# Masukkan nilai siswa:  90
# Masukkan nama siswa:  wirya
# Masukkan absen siswa:  29
# Masukkan nilai siswa:  90
# wirya sudah ada di dalam data ini, silahkan masukkan nama lain
# Masukkan absen yang ingin dicari:  29
# Siswa dengan absen 29 gak ketemu
